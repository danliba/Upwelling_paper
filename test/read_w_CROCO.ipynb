# %%
import xarray as xr
import matplotlib.pyplot as plt
from cmocean import cm # for oceanography-specific colormaps

# %%
ds_w = xr.open_dataset('../../NHCS/hindcast/CROCO_BioEBUS_1990-2010/data/avg_Y2010M10.nc',
                            chunks = {'time':1}).w.isel(s_rho=slice(15,None))
ds_w
# Out:
# <xarray.DataArray 'w' (time: 1, s_rho: 17, eta_rho: 542, xi_rho: 602)> Size: 22MB
# dask.array<getitem, shape=(1, 17, 542, 602), dtype=float32, chunksize=(1, 17, 542, 602), chunktype=numpy.ndarray>
# Coordinates:
#   * eta_rho  (eta_rho) float32 2kB 1.0 2.0 3.0 4.0 ... 539.0 540.0 541.0 542.0
#     lat_rho  (eta_rho, xi_rho) float32 1MB dask.array<chunksize=(542, 602), meta=np.ndarray>
#     lon_rho  (eta_rho, xi_rho) float32 1MB dask.array<chunksize=(542, 602), meta=np.ndarray>
#   * s_rho    (s_rho) float32 68B -0.5156 -0.4844 -0.4531 ... -0.04688 -0.01562
#   * time     (time) float32 4B 6.56e+08
#   * xi_rho   (xi_rho) float32 2kB 1.0 2.0 3.0 4.0 ... 599.0 600.0 601.0 602.0
# Attributes:
#     long_name:      averaged vertical momentum component
#     units:          meter second-1
#     field:          w-velocity, scalar, series
#     standard_name:  upward_sea_water_velocity
#     cell_methods:   time: mean
