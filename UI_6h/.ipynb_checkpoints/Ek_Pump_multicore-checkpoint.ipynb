# %% [markdown]
# ## Ekman Theory

# %% [markdown]
# ### **Wind Speed at Staggered Grid Points**
#
# The wind speed magnitude at u-points (east-west faces) and v-points (north-south faces) is computed by interpolating the perpendicular component and applying:
#
# $$
# \text{ws}_u = \sqrt{u^2 + v_{\text{on\_u}}^2}, \quad \text{ws}_v = \sqrt{u_{\text{on\_v}}^2 + v^2}
# $$
#
# where $v_{\text{on\_u}}$ is $v$ averaged to u-points in the $\xi$ (longitude) direction, and $u_{\text{on\_v}}$ is $u$ averaged to v-points in the $\eta$ (latitude) direction.

# %% [markdown]
# ### **Surface Wind Stress**
#
# Wind stress components at the staggered grid faces are computed using the bulk formula:
#
# $$
# \tau_x^{(u)} = \rho_{\text{air}}\, C_d\, \text{ws}_u \cdot u, \quad \tau_y^{(v)} = \rho_{\text{air}}\, C_d\, \text{ws}_v \cdot v
# $$
#
# where:
# - $\rho_{\text{air}} = 1.22\,\text{kg}\,\text{m}^{-3}$ is air density,
# - $C_d = 1.3 \times 10^{-3}$ is the drag coefficient.
#
# These are then averaged to the rho-points (cell centers):
#
# $$
# \tau_x^{(\rho)} = \frac{1}{2}\left(\tau_x^{(u)}_{i} + \tau_x^{(u)}_{i+1}\right), \qquad \tau_y^{(\rho)} = \frac{1}{2}\left(\tau_y^{(v)}_{j} + \tau_y^{(v)}_{j+1}\right)
# $$

# %% [markdown]
# ### **Grid Metrics (Δx, Δy)**
#
# Horizontal grid spacings on the spherical Earth (radius $A = 6{,}371{,}000\,\text{m}$) are:
#
# $$
# \Delta x = A\,\cos(\phi)\,\Delta\lambda, \quad \Delta y = A\,\Delta\phi
# $$
#
# where $\phi$ is latitude (radians), $\lambda$ is longitude (radians), and $\Delta\lambda$, $\Delta\phi$ are finite differences along $\xi$ and $\eta$ directions.

# %% [markdown]
# ### **Curl of Wind Stress**
#
# The vertical component of the curl (vorticity of the wind stress) is computed via centered finite differences:
#
# $$
# \nabla \times \boldsymbol{\tau} = \frac{\partial \tau_y}{\partial x} - \frac{\partial \tau_x}{\partial y}
# $$
#
# Discretized on the interior cell centers:
#
# $$
# \bigl(\nabla \times \boldsymbol{\tau}\bigr)_{i,j} = \frac{\tau_y^{(\rho)}_{i+1,j} - \tau_y^{(\rho)}_{i,j}}{\Delta x_{i,j}} - \frac{\tau_x^{(\rho)}_{i,j+1} - \tau_x^{(\rho)}_{i,j}}{\Delta y_{i,j}}
# $$

# %% [markdown]
# ### **Coriolis Parameter**
#
# The Coriolis parameter at cell centers is:
#
# $$
# f = 2\,\Omega\,\sin(\phi)
# $$
#
# where $\Omega = 7.2921 \times 10^{-5}\,\text{rad}\,\text{s}^{-1}$ is Earth's angular velocity, and $\phi$ is the latitude averaged over the four surrounding rho-points. Values where $|f| < 10^{-10}$ (near the equator) are set to NaN to avoid division by zero.

# %% [markdown]
# ### **Ekman Pumping Velocity**
#
# The vertical Ekman pumping velocity (positive upward) at the base of the Ekman layer is:
#
# $$
# w_{\text{Ek}} = \frac{1}{\rho_w\,f}\,\bigl(\nabla \times \boldsymbol{\tau}\bigr)_z
# $$
#
# where $\rho_w = 1025\,\text{kg}\,\text{m}^{-3}$ is seawater density.

# %% [markdown]
# ### **Cell Area**
#
# The area of each interior cell (for spatial integrals) is:
#
# $$
# A_{\text{cell}} = \Delta x \cdot \Delta y
# $$
#
# computed at the curl centers by averaging the edge spacings from neighboring cells.

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import re
from xml.etree import ElementTree as ET
from matplotlib.path import Path
import pandas as pd
from scipy.io import loadmat
from scipy.interpolate import RegularGridInterpolator

# %%
from dask.distributed import Client
from dask import array as da
client = Client(n_workers=8, threads_per_worker=1, memory_limit=30e9)
client
# Out:
# <Client: 'tcp://127.0.0.1:38887' processes=8 threads=8, memory=223.52 GiB>
# 2025-12-13 19:36:59,609 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-c0501e823c8d23cb87ed0cf2d0611a9a', 68, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: waiting
# old run_spec: (<function execute_task at 0x1500d9445e40>, (('rechunk-getitem-c0501e823c8d23cb87ed0cf2d0611a9a', 68, 0, 0),), {})
# new run_spec: (<function execute_task at 0x1500d9445e40>, (('rechunk-p2p-2a1de19d8d6711b8058bd2e0c7c122ea', 68, 0, 0),), {})
# old token: ('tuple', (('913ceb5b5beb463a9010ec0790bc30002ca34164', []), ('tuple', (('tuple', ('rechunk-getitem-c0501e823c8d23cb87ed0cf2d0611a9a', 68, 0, 0)),)), ('dict', ())))
# new token: ('tuple', (('913ceb5b5beb463a9010ec0790bc30002ca34164', []), ('tuple', (('tuple', ('rechunk-p2p-2a1de19d8d6711b8058bd2e0c7c122ea', 68, 0, 0)),)), ('dict', ())))
# old dependencies: {('rechunk-getitem-c0501e823c8d23cb87ed0cf2d0611a9a', 68, 0, 0)}
# new dependencies: {('rechunk-p2p-2a1de19d8d6711b8058bd2e0c7c122ea', 68, 0, 0)}
#
# 2025-12-13 19:36:59,611 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-174a38cebc1266758010c39be7476880', 68, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: waiting
# old run_spec: (<function execute_task at 0x1500d9445e40>, (('rechunk-p2p-208bca61a452ab94d91b7b571e5fab1b', 68, 0, 0),), {})
# new run_spec: (<function execute_task at 0x1500d9445e40>, (('rechunk-getitem-174a38cebc1266758010c39be7476880', 68, 0, 0),), {})
# old token: ('tuple', (('913ceb5b5beb463a9010ec0790bc30002ca34164', []), ('tuple', (('tuple', ('rechunk-p2p-208bca61a452ab94d91b7b571e5fab1b', 68, 0, 0)),)), ('dict', ())))
ialized by task ('rechunk-merge-rechunk-transfer-208bca61a452ab94d91b7b571e5fab1b', 58, 0, 0, 292, 0, 0) executed on worker tcp://127.0.0.1:40445
# 2025-12-13 19:46:17,232 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fa9974eb40b797e566258a12c7353cfd deactivated due to stimulus 'task-erred-1765651577.2317443'
# 2025-12-13 19:46:18,701 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle bcaf760222f795b60a3d19d40711fe98 initialized by task ('rechunk-merge-rechunk-transfer-208bca61a452ab94d91b7b571e5fab1b', 59, 0, 0, 299, 0, 0) executed on worker tcp://127.0.0.1:35935
# 2025-12-13 19:46:19,277 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle bcaf760222f795b60a3d19d40711fe98 deactivated due to stimulus 'task-erred-1765651579.2767873'
# 2025-12-13 19:46:19,935 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7f2c798e231973e2257eb16705700b77 initialized by task ('rechunk-merge-rechunk-transfer-208bca61a452ab94d91b7b571e5fab1b', 60, 0, 0, 304, 0, 0) executed on worker tcp://127.0.0.1:37773
# 2025-12-13 19:46:19,943 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7f2c798e231973e2257eb16705700b77 deactivated due to stimulus 'task-erred-1765651579.9409378'

# %% [markdown]
# ### Functions

# %%
#### Inshore mask
## kml to struct
import re
from xml.etree import ElementTree as ET
import numpy as np

def kml2struct(kml_file):
    """
    Import a .kml file as a list of dictionary structures with fields:
    Geometry, Name, Description, Lon, Lat, and BoundingBox.
    """
    # Read the KML file
    try:
        with open(kml_file, 'r', encoding='utf-8') as file:
            txt = file.read()
    except Exception as e:
        raise FileNotFoundError(f"Unable to open file {kml_file}: {e}")

    # Regular expression to match Placemark tags
    expr = r"<Placemark.+?>.+?</Placemark>"
    object_strings = re.findall(expr, txt, re.DOTALL)
    
    kml_struct = []

    for obj_str in object_strings:
        # Extract Name
        name_match = re.search(r"<name.*?>(.*?)</name>", obj_str, re.DOTALL)
        name = name_match.group(1).strip() if name_match else "undefined"

        # Extract Description
        desc_match = re.search(r"<description.*?>(.*?)</description>", obj_str, re.DOTALL)
        desc = desc_match.group(1).strip() if desc_match else ""

        # Determine Geometry Type
        geometry = ""
        if "<Point" in obj_str:
            geometry = "Point"
        elif "<LineString" in obj_str:
            geometry = "Line"
        elif "<Polygon" in obj_str:
            geometry = "Polygon"

        # Extract Coordinates
        coord_match = re.search(r"<coordinates.*?>(.*?)</coordinates>", obj_str, re.DOTALL)
        if not coord_match:
            continue  # Skip if no coordinates are found
        coord_str = coord_match.group(1).strip()
        coord_list = np.array([list(map(float, coord.split(','))) for coord in coord_str.split()])

        # Separate Lon, Lat, and handle Polygons
        lon = coord_list[:, 0]
        lat = coord_list[:, 1]
        if geometry == "Polygon":
            # Close the polygon by appending NaN
            lon = np.append(lon, np.nan)
            lat = np.append(lat, np.nan)

        # Create BoundingBox
        bounding_box = [[lon.min(), lat.min()], [lon.max(), lat.max()]]

        # Append to kml_struct
        kml_struct.append({
            "Geometry": geometry,
            "Name": name,
            "Description": desc,
            "Lon": lon,
            "Lat": lat,
            "BoundingBox": bounding_box
        })

    return kml_struct

# %%
arch_kml_zona1 = "/gxfs_work/geomar/smomw662/NHCS/hindcast/CROCO_BioEBUS_1990-2010/indices/BK111km.kml"
R1 = kml2struct(arch_kml_zona1)

# Extract Lon and Lat from the first polygon
lonb1 = R1[0]["Lon"]
latb1 = R1[0]["Lat"]

# %%
ds_ = xr.open_dataset('/gxfs_work/geomar/smomw662/NHCS/hincast_1980-2015/croco_avg_Y1980M01.nc', 
                     chunks = {'time':1})
ds_
# Out:
# <xarray.Dataset> Size: 891MB
# Dimensions:     (xi_rho: 602, xi_u: 601, eta_rho: 542, eta_v: 541, s_rho: 32,
#                  s_w: 33, time: 1, auxil: 4)
# Coordinates: (12/13)
#   * xi_rho      (xi_rho) float64 5kB 1.0 2.0 3.0 4.0 ... 599.0 600.0 601.0 602.0
#   * xi_u        (xi_u) float64 5kB 1.5 2.5 3.5 4.5 ... 598.5 599.5 600.5 601.5
#   * eta_rho     (eta_rho) float64 4kB 1.0 2.0 3.0 4.0 ... 540.0 541.0 542.0
#   * eta_v       (eta_v) float64 4kB 1.5 2.5 3.5 4.5 ... 538.5 539.5 540.5 541.5
#   * s_rho       (s_rho) float64 256B -0.9844 -0.9531 ... -0.04688 -0.01562
#   * s_w         (s_w) float64 264B -1.0 -0.9688 -0.9375 ... -0.0625 -0.03125 0.0
#     ...          ...
#     lat_rho     (eta_rho, xi_rho) float64 3MB dask.array<chunksize=(542, 602), meta=np.ndarray>
#     lon_u       (eta_rho, xi_u) float64 3MB dask.array<chunksize=(542, 601), meta=np.ndarray>
#     lat_u       (eta_rho, xi_u) float64 3MB dask.array<chunksize=(542, 601), meta=np.ndarray>
#     lon_v       (eta_v, xi_rho) float64 3MB dask.array<chunksize=(541, 602), meta=np.ndarray>
#     lat_v       (eta_v, xi_rho) float64 3MB dask.array<chunksize=(541, 602), meta=np.ndarray>
#   * time        (time) float32 4B 1.339e+06
# Dimensions without coordinates: auxil
# Data variables: (12/54)
#     spherical   |S1 1B ...
#     xl          float64 8B ...
#     el          float64 8B ...
#     Vtransform  float64 8B ...
#     sc_r        (s_rho) float64 256B dask.array<chunksize=(32,), meta=np.ndarray>
#     sc_w        (s_w) float64 264B dask.array<chunksize=(33,), meta=np.ndarray>
#     ...          ...
#     swflux      (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
#     radsw       (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
#     shflx_rlw   (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
#     shflx_lat   (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
#     shflx_sen   (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
#     hel         (time, eta_rho, xi_rho) float32 1MB dask.array<chunksize=(1, 542, 602), meta=np.ndarray>
# Attributes: (12/57)
#     type:           ROMS restart file
#     title:          Peru UW Interannual Run
#     date:
#     rst_file:       croco_rst.nc
#     his_file:       croco_his.nc
#     avg_file:       croco_avg.nc
#     ...             ...
#     gamma2_expl:    Slipperiness parameter
#     x_sponge:       0.0
#     v_sponge:       0.0
#     sponge_expl:    Sponge parameters : extent (m) & viscosity (m2.s-1)
#     SRCS:           main.F step.F read_inp.F timers_roms.F init_scalars.F ini...
#     CPP-options:    REGIONAL PERU_UW MPI OBC_WEST OBC_NORTH OBC_SOUTH BIOLOGY...

# %%
LON, LAT = np.meshgrid(ds_.lon_rho.compute().values[0,:],ds_.lat_rho.compute().values[:,0])
# Create a path from the polygon coordinates
polygon = Path(np.column_stack((lonb1, latb1)))

# Flatten the LON and LAT to create coordinate pairs
lonlat_points = np.column_stack((LON.ravel(), LAT.ravel()))

# Check which points are inside the polygon
mask = polygon.contains_points(lonlat_points).reshape(LON.shape)

# Convert the mask to NaN for the outshore region
inshore_mask = np.where(mask, 1, np.nan)

mask_rho = ds_.mask_rho.values 
mask_nan = np.where(mask_rho, 1, np.nan)

# %% [markdown]
# ## Data

# %%
import glob

files = sorted(glob.glob('/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y*M*_uwnd_vwnd.nc'))
print(len(files), files[:5], files[-5:])

# Peek at first two
for f in files[:3]:
    with xr.open_dataset(f) as ds:
        print(f, ds['bulk_time'].load().values[:3], ds['bulk_time'].load().values[-3:])
# Out:
# 432 ['/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M10_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M11_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M12_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M1_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M2_uwnd_vwnd.nc'] ['/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y2015M5_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y2015M6_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y2015M7_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y2015M8_uwnd_vwnd.nc', '/gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y2015M9_uwnd_vwnd.nc']
# /gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M10_uwnd_vwnd.nc [23666399121093747 23670000878906252 23673600000000000] [26348400878906252 26352000000000000 26355599121093747]
# /gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M11_uwnd_vwnd.nc [26344799121093747 26348400878906252 26352000000000000] [28940400878906252 28944000000000000 28947599121093747]
# /gxfs_work/geomar/smomw662/NHCS/Winds_input/Winds_6h/extracted_winds/croco_blk_ERA5_Y1980M12_uwnd_vwnd.nc [28936799121093747 28940400878906252 28944000000000000] [31618800878906252 31622400000000000 31625999121093747]

# %%
## improve the chunking as it should be 4320 time so a month
ds = xr.open_mfdataset(
    files,
    combine='nested',
    concat_dim='bulk_time',  # name of the time coordinate/dimension to concat
    parallel=True,
    chunks=
        'auto'# Half the spatial dimension
)
ds = ds[['uwnd', 'vwnd']]
ds = ds.chunk({
        'bulk_time': 1000,
        'eta_u': 270,     # Half the spatial dimension
        'xi_u': 300, 
        'eta_v':270 ,
        'xi_v':300 ,# Half the spatial dimension
    })
ds
# Out:
# <xarray.Dataset> Size: 2TB
# Dimensions:    (bulk_time: 317304, eta_u: 542, xi_u: 601, eta_v: 541, xi_v: 602)
# Coordinates:
#   * bulk_time  (bulk_time) timedelta64[ns] 3MB 273 days 21:59:59.121093747 .....
# Dimensions without coordinates: eta_u, xi_u, eta_v, xi_v
# Data variables:
#     uwnd       (bulk_time, eta_u, xi_u) float64 827GB dask.array<chunksize=(1000, 270, 300), meta=np.ndarray>
#     vwnd       (bulk_time, eta_v, xi_v) float64 827GB dask.array<chunksize=(1000, 270, 300), meta=np.ndarray>
# Attributes:
#     title:        Peru UW Model
#     date:         27-Sep-2023
#     grd_file:     /gxfs_work1/fs1/work-geomar/smomw398/croco_tool/croco_tools...
#     type:         CROCO heat flux bulk forcing file
#     origin_date:  01-Aug-1980 00:00:00
#     product:      ERA5
#     history:      Sat Dec 13 03:15:56 2025: ncks -v uwnd,vwnd ./croco_blk_ERA...
#     NCO:          netCDF Operators version 5.1.5 (Homepage = http://nco.sf.ne...

# %%
origin = np.datetime64('1980-01-01T00:00:00')  # example; choose your true origin
abs_time = origin + ds.bulk_time

# Example: extract calendar year and month with pandas
pdt = pd.DatetimeIndex(abs_time.values.astype('datetime64[ns]'))
year  = xr.DataArray(pdt.year,  coords=ds.bulk_time.coords, dims=ds.bulk_time.dims, name='year')
month = xr.DataArray(pdt.month, coords=ds.bulk_time.coords, dims=ds.bulk_time.dims, name='month')
day   = xr.DataArray(pdt.day,   coords=ds.bulk_time.coords, dims=ds.bulk_time.dims, name='day')
hour   = xr.DataArray(pdt.hour,   coords=ds.bulk_time.coords, dims=ds.bulk_time.dims, name='hour')

# %%
ds = ds.assign_coords(
    year = (('bulk_time',), year.values),
    month = (('bulk_time',), month.values),
    day = (('bulk_time',), day.values),
    hour = (('bulk_time',), hour.values),
)

time = xr.DataArray(abs_time.astype('datetime64[ns]'),
                    coords=ds.bulk_time.coords, dims=ds.bulk_time.dims, name='time')

# Add it as a coordinate and keep bulk_time as-is
ds = ds.assign_coords(time=('bulk_time', time.values))

ds
# Out:
# <xarray.Dataset> Size: 2TB
# Dimensions:    (bulk_time: 317304, eta_u: 542, xi_u: 601, eta_v: 541, xi_v: 602)
# Coordinates:
#   * bulk_time  (bulk_time) timedelta64[ns] 3MB 273 days 21:59:59.121093747 .....
#     year       (bulk_time) int32 1MB 1980 1980 1980 1980 ... 2015 2015 2015 2015
#     month      (bulk_time) int32 1MB 9 9 10 10 10 10 10 10 ... 9 9 9 9 9 9 10 10
#     day        (bulk_time) int32 1MB 30 30 1 1 1 1 1 1 ... 30 30 30 30 30 30 1 1
#     hour       (bulk_time) int32 1MB 21 23 0 0 2 3 3 5 ... 18 19 19 21 22 22 0 1
#     time       (bulk_time) datetime64[ns] 3MB 1980-09-30T21:59:59.121093747 ....
# Dimensions without coordinates: eta_u, xi_u, eta_v, xi_v
# Data variables:
#     uwnd       (bulk_time, eta_u, xi_u) float64 827GB dask.array<chunksize=(1000, 270, 300), meta=np.ndarray>
#     vwnd       (bulk_time, eta_v, xi_v) float64 827GB dask.array<chunksize=(1000, 270, 300), meta=np.ndarray>
# Attributes:
#     title:        Peru UW Model
#     date:         27-Sep-2023
#     grd_file:     /gxfs_work1/fs1/work-geomar/smomw398/croco_tool/croco_tools...
#     type:         CROCO heat flux bulk forcing file
#     origin_date:  01-Aug-1980 00:00:00
#     product:      ERA5
#     history:      Sat Dec 13 03:15:56 2025: ncks -v uwnd,vwnd ./croco_blk_ERA...
#     NCO:          netCDF Operators version 5.1.5 (Homepage = http://nco.sf.ne...

# %%
# import numpy as np
# import xarray as xr

# A: Earth radius (meters)
A = 6371000.0

# Ensure uwnd and vwnd are in the expected order and dims (time, eta_u, xi_u), (time, eta_v, xi_v)
u = xr.DataArray(
    ds['uwnd'].data,
    dims=('time','eta_u','xi_u'),
    coords=dict(
        time=ds.time.data,
        lat_u=(('eta_u','xi_u'), ds_.lat_u.compute().values),
        lon_u=(('eta_u','xi_u'), ds_.lon_u.compute().values),
    ),
    name='u10'
)

v = xr.DataArray(
    ds['vwnd'].data,
    dims=('time','eta_v','xi_v'),
    coords=dict(
        time=ds.time.data,
        lat_v=(('eta_v','xi_v'), ds_.lat_v.compute().values),
        lon_v=(('eta_v','xi_v'), ds_.lon_v.compute().values),
    ),
    name='v10'
)

# ----------------------------
# Compute wind speed at faces with proper alignment
# ----------------------------
# Map v to u points: average in xi (x) direction -> loses 1 cell in xi
v_on_u = 0.5 * (
    v.isel(xi_v=slice(0, -1)).rename({'eta_v':'eta_u', 'xi_v':'xi_u'}) +
    v.isel(xi_v=slice(1,  None)).rename({'eta_v':'eta_u', 'xi_v':'xi_u'})
)

# Align shapes by trimming to common interior
eta_u_size = min(u.sizes['eta_u'], v_on_u.sizes['eta_u'])
xi_u_size  = min(u.sizes['xi_u'],  v_on_u.sizes['xi_u'])

u_c      = u.isel(eta_u=slice(0, eta_u_size), xi_u=slice(0, xi_u_size))
v_on_u_c = v_on_u.isel(eta_u=slice(0, eta_u_size), xi_u=slice(0, xi_u_size))

# Map u to v points: average in eta (y) direction -> loses 1 cell in eta
u_on_v = 0.5 * (
    u.isel(eta_u=slice(0, -1)).rename({'eta_u':'eta_v', 'xi_u':'xi_v'}) +
    u.isel(eta_u=slice(1,  None)).rename({'eta_u':'eta_v', 'xi_u':'xi_v'})
)

# Align shapes
eta_v_size = min(v.sizes['eta_v'], u_on_v.sizes['eta_v'])
xi_v_size  = min(v.sizes['xi_v'],  u_on_v.sizes['xi_v'])

v_c      = v.isel(eta_v=slice(0, eta_v_size), xi_v=slice(0, xi_v_size))
u_on_v_c = u_on_v.isel(eta_v=slice(0, eta_v_size), xi_v=slice(0, xi_v_size))

# Wind speed magnitudes at u and v faces
ws_u = xr.apply_ufunc(np.hypot, u_c, v_on_u_c,dask='allowed')  # (time, eta_u_size, xi_u_size)
ws_v = xr.apply_ufunc(np.hypot, u_on_v_c, v_c,dask='allowed')  # (time, eta_v_size, xi_v_size)

# ----------------------------
# Surface wind stresses at faces
# ----------------------------
rho_air = 1.22
Cd = 1.3e-3
taux_u = rho_air * Cd * ws_u * u_c
tauy_v = rho_air * Cd * ws_v * v_c

# ----------------------------
# Average stresses to rho points
# ----------------------------
# tau_x from u -> rho (average in xi)
taux_rho = 0.5 * (
    taux_u.isel(xi_u=slice(0, -1)).rename({'eta_u':'eta_rho','xi_u':'xi_rho'}) +
    taux_u.isel(xi_u=slice(1,  None)).rename({'eta_u':'eta_rho','xi_u':'xi_rho'})
)

# tau_y from v -> rho (average in eta)
tauy_rho = 0.5 * (
    tauy_v.isel(eta_v=slice(0, -1)).rename({'eta_v':'eta_rho','xi_v':'xi_rho'}) +
    tauy_v.isel(eta_v=slice(1,  None)).rename({'eta_v':'eta_rho','xi_v':'xi_rho'})
)

# Align tau arrays to common rho grid size
eta_rho_size = min(taux_rho.sizes['eta_rho'], tauy_rho.sizes['eta_rho'])
xi_rho_size  = min(taux_rho.sizes['xi_rho'],  tauy_rho.sizes['xi_rho'])

taux_rho = taux_rho.isel(eta_rho=slice(0, eta_rho_size), xi_rho=slice(0, xi_rho_size))
tauy_rho = tauy_rho.isel(eta_rho=slice(0, eta_rho_size), xi_rho=slice(0, xi_rho_size))

# %%
# Attach 2D rho coords (trimmed to match)
# lat_rho = xr.DataArray(
#     ds_.lat_rho.values[:eta_rho_size, :xi_rho_size], 
#     dims=('eta_rho','xi_rho'), 
#     name='lat'
# )
# lon_rho = xr.DataArray(
#     ds_.lon_rho.values[:eta_rho_size, :xi_rho_size], 
#     dims=('eta_rho','xi_rho'), 
#     name='lon'
# )

lat_rho = xr.DataArray(
    ds_.lat_rho.isel(eta_rho=slice(0, eta_rho_size),
                     xi_rho =slice(0, xi_rho_size)).values,
    dims=('eta_rho','xi_rho'),
    name='lat'
)

lon_rho = xr.DataArray(
    ds_.lon_rho.isel(eta_rho=slice(0, eta_rho_size),
                     xi_rho =slice(0, xi_rho_size)).values, 
    dims=('eta_rho','xi_rho'), 
    name='lon'
)

# %%
taux_rho = taux_rho.assign_coords(lat=lat_rho, lon=lon_rho)
tauy_rho = tauy_rho.assign_coords(lat=lat_rho, lon=lon_rho)

# taux_rho = taux_rho.chunk({'time': 1000, 'eta_rho': 100, 'xi_rho': 100})
# tauy_rho = tauy_rho.chunk({'time': 1000, 'eta_rho': 100, 'xi_rho': 100})

taux_rho = taux_rho.persist()
tauy_rho = tauy_rho.persist()

# %%
# ----------------------------
# Grid metrics (Δx, Δy) on rho grid
# ----------------------------
# Differences along xi (longitude) and eta (latitude)
dlam = np.deg2rad(lon_rho.diff('xi_rho'))                   # (eta_rho, xi_rho-1)
lat_x = 0.5 * (lat_rho.isel(xi_rho=slice(0,-1)) + lat_rho.isel(xi_rho=slice(1,None)))
dx = A * np.cos(np.deg2rad(lat_x)) * dlam                   # (eta_rho, xi_rho-1)

dphi = np.deg2rad(lat_rho.diff('eta_rho'))                  # (eta_rho-1, xi_rho)
dy = A * dphi                                               # (eta_rho-1, xi_rho)

# ----------------------------
# Centered derivatives to common centers
# ----------------------------
# d(tau_y)/dx lives on (eta_rho, xi_rho-1)
dtauy_dx_edge = (tauy_rho.isel(xi_rho=slice(1, None)) - tauy_rho.isel(xi_rho=slice(0, -1))) / dx

# d(tau_x)/dy lives on (eta_rho-1, xi_rho)
dtaux_dy_edge = (taux_rho.isel(eta_rho=slice(1, None)) - taux_rho.isel(eta_rho=slice(0, -1))) / dy

# Average both to interior cell centers (eta_rho-1, xi_rho-1)
dtauy_dx_c = 0.5 * (dtauy_dx_edge.isel(eta_rho=slice(0, -1)) + dtauy_dx_edge.isel(eta_rho=slice(1, None)))
dtaux_dy_c = 0.5 * (dtaux_dy_edge.isel(xi_rho=slice(0, -1)) + dtaux_dy_edge.isel(xi_rho=slice(1, None)))

# Ensure same sizes for curl computation
eta_c = min(dtauy_dx_c.sizes['eta_rho'], dtaux_dy_c.sizes['eta_rho'])
xi_c  = min(dtauy_dx_c.sizes['xi_rho'],  dtaux_dy_c.sizes['xi_rho'])
dtauy_dx_c = dtauy_dx_c.isel(eta_rho=slice(0, eta_c), xi_rho=slice(0, xi_c))
dtaux_dy_c = dtaux_dy_c.isel(eta_rho=slice(0, eta_c), xi_rho=slice(0, xi_c))

curl_tau = (dtauy_dx_c - dtaux_dy_c)  # (time, eta_c, xi_c)
curl_tau.name = 'curl_tau'

# ----------------------------
# Coriolis parameter at curl centers
# ----------------------------
# Center lat for f (average of the four surrounding rho points)
lat_c = 0.25 * (
    lat_rho.isel(eta_rho=slice(0, eta_c), xi_rho=slice(0, xi_c)) +
    lat_rho.isel(eta_rho=slice(1, eta_c+1), xi_rho=slice(0, xi_c)) +
    lat_rho.isel(eta_rho=slice(0, eta_c), xi_rho=slice(1, xi_c+1)) +
    lat_rho.isel(eta_rho=slice(1, eta_c+1), xi_rho=slice(1, xi_c+1))
)

Omega = 7.2921e-5
f = 2.0 * Omega * np.sin(np.deg2rad(lat_c))
# Avoid divide by zero near equator
f = xr.where(np.abs(f) < 1e-10, np.nan, f)

# ----------------------------
# Ekman pumping velocity
# ----------------------------
rho_w = 1025.0
w_ek = curl_tau / (rho_w * f)
w_ek = w_ek.transpose('time','eta_rho','xi_rho')
w_ek.name = 'w_ek'

# %%
lat_c_da = lat_c  # at curl centers
band = (lat_c_da >= -16) & (lat_c_da <= -5)
band.plot()

# %%
w_ek
# Out:
# <xarray.DataArray 'w_ek' (time: 317304, eta_rho: 539, xi_rho: 599)> Size: 820GB
# dask.array<truediv, shape=(317304, 539, 599), dtype=float64, chunksize=(1000, 267, 297), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 3MB 1980-09-30T21:59:59.121093747 ... 2015...
# Dimensions without coordinates: eta_rho, xi_rho

# %%
wek_ms = w_ek * inshore_mask[:eta_c, :xi_c]* mask_nan[:eta_c, :xi_c]
wek_m2_s = wek_ms * 111e3  # units: (m^2/s)
wek_m2_s = wek_m2_s.chunk({'time':1000,'eta_rho': 200,'xi_rho': 200})

# %%
wek_m2_s.isel(time=1).rename('$m^2\cdot s^{-1}$').plot(robust=True,cmap='RdBu_r')
# Out:
# /opt/conda/lib/python3.11/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 12.39 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
(wek_m2_s.isel(time=0).where(band)).rename('$m^2\cdot s^{-1}$').load().plot()
# Out:
# /opt/conda/lib/python3.11/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 12.70 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2025-12-13 19:41:01,364 - distributed.spill - ERROR - Spill to disk failed; keeping data in memory
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/spill.py", line 124, in _handle_errors
#     yield
#   File "/opt/conda/lib/python3.11/site-packages/distributed/spill.py", line 181, in __setitem__
#     super().__setitem__(key, value)
#   File "/opt/conda/lib/python3.11/site-packages/zict/buffer.py", line 193, in __setitem__
#     self.fast[key] = value
#     ~~~~~~~~~^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/lru.py", line 138, in __setitem__
#     self.evict_until_below_target()
#   File "/opt/conda/lib/python3.11/site-packages/zict/lru.py", line 180, in evict_until_below_target
#     self.evict()
#   File "/opt/conda/lib/python3.11/site-packages/zict/common.py", line 127, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/lru.py", line 227, in evict
#     cb(key, value)
#   File "/opt/conda/lib/python3.11/site-packages/zict/buffer.py", line 139, in fast_to_slow
#     self.slow[key] = value
#     ~~~~~~~~~^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/common.py", line 127, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/cache.py", line 89, in __setitem__
#     self.data[key] = value
#     ~~~~~~~~~^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/spill.py", line 351, in __setitem__
#     self.d[key] = pickled
#     ~~~~~~^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/common.py", line 127, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/zict/file.py", line 135, in __setitem__
#     fh.writelines(value)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,374 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,388 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,427 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,427 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,749 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,751 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,752 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,754 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,754 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,876 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,963 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,964 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:01,984 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,451 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,450 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,452 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,453 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,455 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,461 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,662 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,690 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,691 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,710 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,710 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,711 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,715 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,721 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,752 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,753 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,758 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,762 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,766 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,767 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,848 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,852 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:02,924 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:03,044 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:03,094 - distributed.shuffle._disk - ERROR - [Errno 28] No space left on device
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:03,537 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:04,073 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:04,215 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,534 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,535 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,536 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,538 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 180, in _process
#     with open(self.directory / str(id), mode="ab") as f:
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,545 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:41:05,545 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# 2025-12-13 19:42:53,829 - distributed.worker - ERROR - Compute Failed
# Key:       ('rechunk-merge-rechunk-transfer-208bca61a452ab94d91b7b571e5fab1b', 258, 0, 0, 1294, 0, 0)
# State:     executing
# Function:  execute_task
# args:      ((<function rechunk_transfer at 0x1529e74edc60>, (<function concatenate3 at 0x1529bcc86ac0>, [[[array([[[-3.18938425, -3.20673197, -3.22193633, ...,  9.03527741,
#           9.03527741,  9.03527741],
#         [-3.21221379, -3.22208745, -3.22643046, ...,  9.02665207,
#           9.02665207,  9.02665207],
#         [-3.20108617, -3.2032782 , -3.19695638, ...,  9.02845679,
#           9.02845679,  9.0284568 ],
#         ...,
#         [-5.44755194, -5.41121763, -5.37599852, ..., -1.10806498,
#          -1.11865775, -1.1232204 ],
#         [-5.69824585, -5.65745316, -5.61364562, ..., -1.10825129,
#          -1.11867844, -1.12317573],
#         [-5.91972183, -5.87456926, -5.82434385, ..., -1.10752984,
#          -1.11856389, -1.12330075]],
#
#        [[-3.79278442, -3.81002045, -3.82518767, ...,  9.2972627 ,
#           9.29726271,  9.29726271],
#         [-3.82292736, -3.82792784, -3.82874633, ...,  9.33644224,
#           9.33644225,  9.33644225],
#         [-3.8108078 , -3.80181345, -3.78622901, ...,  9.38205827,
#
# kwargs:    {}
# Exception: "RuntimeError('P2P shuffling 4adc7c5706601d4a29f9dbf4529a44dd failed during transfer phase')"
# Traceback: '  File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 170, in rechunk_transfer\n    with handle_transfer_errors(id):\n  File "/opt/conda/lib/python3.11/contextlib.py", line 158, in __exit__\n    self.gen.throw(typ, value, traceback)\n  File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 512, in handle_transfer_errors\n    raise RuntimeError(f"P2P shuffling {id} failed during transfer phase") from e\n'
#
# 2025-12-13 19:42:53,932 - distributed.core - ERROR - Exception while handling op shuffle_receive
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 319, in shuffle_receive
#     shuffle_run = await self._get_shuffle_run(shuffle_id, run_id)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 375, in _get_shuffle_run
#     return await self.shuffle_runs.get_with_run_id(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 131, in get_with_run_id
#     raise shuffle_run._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_worker_plugin.py", line 320, in shuffle_receive
#     return await shuffle_run.receive(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 317, in receive
#     await self._receive(data)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_rechunk.py", line 1029, in _receive
#     await self._write_to_disk(shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_core.py", line 264, in _write_to_disk
#     await self._disk_buffer.write(
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 194, in write
#     raise self._exception
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_buffer.py", line 113, in process
#     await self._process(id, shards)
#   File "/opt/conda/lib/python3.11/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/distributed/shuffle/_disk.py", line 181, in _process
#     f.writelines(frames)
# OSError: [Errno 28] No space left on device
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/zict/buffer.py:184, in __getitem__()
#     183 try:
# --> 184     return self.fast[key]
#     185 except KeyError:
#
# File /opt/conda/lib/python3.11/site-packages/zict/common.py:127, in wrapper()
#     126 with self.lock:
# --> 127     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/zict/lru.py:117, in __getitem__()
#     115 @locked
#     116 def __getitem__(self, key: KT) -> VT:
# --> 117     result = self.d[key]
#     118     self.order.remove(key)
#
# KeyError: ('rechunk-merge-67404de259f19b9e993f4382b2c8ebff', 0, 0, 1)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 (wek_m2_s.isel(time=0).where(band)).rename('$m^2\cdot s^{-1}$').load().plot()
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataarray.py:1170, in DataArray.load(self, **kwargs)
#    1150 def load(self, **kwargs) -> Self:
#    1151     """Manually trigger loading of this array's data from disk or a
#    1152     remote source into memory and return this array.
#    1153
#    (...)
#    1168     dask.compute
#    1169     """
# -> 1170     ds = self._to_temp_dataset().load(**kwargs)
#    1171     new = self._from_temp_dataset(ds)
#    1172     self._variable = new._variable
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataset.py:870, in Dataset.load(self, **kwargs)
#     867 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     869 # evaluate all the chunked arrays simultaneously
# --> 870 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     871     *lazy_data.values(), **kwargs
#     872 )
#     874 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     875     self.variables[k].data = data
#
# File /opt/conda/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/conda/lib/python3.11/site-packages/distributed/spill.py:216, in __getitem__()
#     213     context_meter.digest_metric("memory-read", 1, "count")
#     214     context_meter.digest_metric("memory-read", memory_size, "bytes")
# --> 216 return super().__getitem__(key)
#
# File /opt/conda/lib/python3.11/site-packages/zict/common.py:127, in wrapper()
#     125 self = cast(ZictBase, args[0])
#     126 with self.lock:
# --> 127     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/zict/buffer.py:186, in __getitem__()
#     184     return self.fast[key]
#     185 except KeyError:
# --> 186     return self.slow_to_fast(key)
#
# File /opt/conda/lib/python3.11/site-packages/zict/buffer.py:175, in slow_to_fast()
#     172     del self.slow[key]
#     174 with self.unlock():
# --> 175     self.fast.evict_until_below_target()
#     176     for cb in self.slow_to_fast_callbacks:
#     177         cb(key, value)
#
# File /opt/conda/lib/python3.11/site-packages/zict/lru.py:180, in evict_until_below_target()
#     178 while self.total_weight + self.offset > n and not self.closed:
#     179     try:
# --> 180         self.evict()
#     181     except KeyError:
#     182         return
#
# File /opt/conda/lib/python3.11/site-packages/zict/common.py:127, in wrapper()
#     125 self = cast(ZictBase, args[0])
#     126 with self.lock:
# --> 127     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/zict/lru.py:227, in evict()
#     224 with self.unlock():
#     225     # This may raise; e.g. if a callback tries storing to a full disk
#     226     for cb in self.on_evict:
# --> 227         cb(key, value)
#     229     if self._cancel_evict[key]:
#     230         for cb in self.on_cancel_evict:
#
# File /opt/conda/lib/python3.11/site-packages/zict/buffer.py:139, in fast_to_slow()
#     138 def fast_to_slow(self, key: KT, value: VT) -> None:
# --> 139     self.slow[key] = value
#     140     try:
#     141         for cb in self.fast_to_slow_callbacks:
#
# File /opt/conda/lib/python3.11/site-packages/zict/common.py:127, in wrapper()
#     125 self = cast(ZictBase, args[0])
#     126 with self.lock:
# --> 127     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/zict/cache.py:89, in __setitem__()
#      86 self._last_updated[key] = self._gen = gen
#      88 with self.unlock():
# ---> 89     self.data[key] = value
#      91 if key not in self._last_updated:
#      92     # Another thread called __delitem__ in the meantime
#      93     discard(self.data, key)
#
# File /opt/conda/lib/python3.11/site-packages/distributed/spill.py:351, in __setitem__()
#     348 # Store to disk through File.
#     349 # This may raise OSError, which is caught by SpillBuffer above.
#     350 with context_meter.meter("disk-write", "seconds"):
# --> 351     self.d[key] = pickled
#     352 context_meter.digest_metric("disk-write", 1, "count")
#     353 context_meter.digest_metric("disk-write", pickled_size, "bytes")
#
# File /opt/conda/lib/python3.11/site-packages/zict/common.py:127, in wrapper()
#     125 self = cast(ZictBase, args[0])
#     126 with self.lock:
# --> 127     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/zict/file.py:135, in __setitem__()
#     133 with open(os.path.join(self.directory, fn), "wb") as fh, self.unlock():
#     134     if isinstance(value, (tuple, list)):
# --> 135         fh.writelines(value)
#     136     else:
#     137         fh.write(value)
#
# OSError: [Errno 28] No space left on device

# %%
#ms
wek_ms_ = (wek_ms.where(band)).mean(dim=('xi_rho')).sortby('time')  # m2/s
#m2/s
wek_m2_s_ = (wek_m2_s.where(band)).mean(dim=('xi_rho')).sortby('time')  # m^2/s
wek_m2_s_

# %%
wek_ms_.isel(time=0).dropna('eta_rho').load().rename('$m\cdot s^{-1}$').plot()

# %%
wek_m2_s_.isel(time=0).dropna('eta_rho').load().rename('$m^2\cdot s^{-1}$').plot()

# %%
lat=lat_c_da.isel(xi_rho=0)

# %%
wek_m2_s_['lat'] = lat

# %%
wek_m2_s_.attrs["units"] = "m2/s"
wek_m2_s_.attrs["long_name"] = "Ekman pumping (area flux)"


wek_m2_s_ = wek_m2_s_.swap_dims({'eta_rho':'lat'})
wek_m2_s_
# Pump.rename({"eta_rho": "lat"})
# Pump_m2s.to_dataset(name='Pump').to_netcdf('Pump.nc')

# %%
wek_m2_s_=wek_m2_s_.chunk({'time': 50000})
wek_m2_s_

# %%
# wek_m2_s_.to_dataset(name='Pump').to_netcdf('Pump_m2s.nc')
Pump = wek_m2_s_.load()
Pump

# %%
Pump.to_netcdf('Pump.nc')
